# %% [markdown]
# # Facebook Data Crawling
# In this notebook, we will be crawling data from Facebook using the Facebook Graph API. We will be using the facebook-scraper

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Install the required library
# We will be using the facebook-scraper library to crawl data from Facebook. We will install this library using pip.

# %%
# %pip install facebook_scraper pandas numpy
# Out:
# Collecting facebook_scraper
#   Downloading facebook_scraper-0.2.59-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Collecting dateparser<2.0.0,>=1.0.0 (from facebook_scraper)
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 7.4 MB/s eta 0:00:00
# Collecting demjson3<4.0.0,>=3.0.5 (from facebook_scraper)
#   Downloading demjson3-3.0.6.tar.gz (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.5/131.5 kB 18.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting requests-html<0.11.0,>=0.10.0 (from facebook_scraper)
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.10/dist-packages (from dateparser<2.0.0,>=1.0.0->facebook_scraper) (2023.6.3)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser<2.0.0,>=1.0.0->facebook_scraper) (5.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from requests-html<0.11.0,>=0.10.0->facebook_scraper) (2.31.0)
# Collecting pyquery (from requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading pyquery-2.0.0-py3-none-any.whl (22 kB)
# Collecting fake-useragent (from requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading fake_useragent-1.4.0-py3-none-any.whl (15 kB)
# Collecting parse (from requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading parse-1.20.0-py2.py3-none-any.whl (19 kB)
# Collecting bs4 (from requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py) ... done
# Collecting w3lib (from requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading w3lib-2.1.2-py3-none-any.whl (21 kB)
# Collecting pyppeteer>=0.0.14 (from requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.4/83.4 kB 9.6 MB/s eta 0:00:00
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (1.4.4)
# Requirement already satisfied: certifi>=2021 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (2023.11.17)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (6.8.0)
# Collecting pyee<9.0.0,>=8.1.0 (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.66.1)
# Collecting urllib3<2.0.0,>=1.25.8 (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 15.7 MB/s eta 0:00:00
# Collecting websockets<11.0,>=10.0 (from pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from bs4->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.11.2)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.10/dist-packages (from pyquery->requests-html<0.11.0,>=0.10.0->facebook_scraper) (4.9.3)
# Collecting cssselect>=1.2.0 (from pyquery->requests-html<0.11.0,>=0.10.0->facebook_scraper)
#   Downloading cssselect-1.2.0-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook_scraper) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->requests-html<0.11.0,>=0.10.0->facebook_scraper) (3.6)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html<0.11.0,>=0.10.0->facebook_scraper) (3.17.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->bs4->requests-html<0.11.0,>=0.10.0->facebook_scraper) (2.5)
# Building wheels for collected packages: demjson3, bs4
#   Building wheel for demjson3 (setup.py) ... done
#   Created wheel for demjson3: filename=demjson3-3.0.6-py3-none-any.whl size=75280 sha256=b5cca7c515149e2a9b38e387a5a28acac7c51cadb7fcf75baeaf2d3e45eafbd7
#   Stored in directory: /root/.cache/pip/wheels/2d/32/af/75c810e14c7ca0df40c20c662fcc7f33d1e055937b4e452cc1
#   Building wheel for bs4 (setup.py) ... done
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1256 sha256=72a13770ceb86fe4c2941dd3fd5398f6b21f23728e64ed89f84c4a7eaf9c1917
#   Stored in directory: /root/.cache/pip/wheels/25/42/45/b773edc52acb16cd2db4cf1a0b47117e2f69bb4eb300ed0e70
# Successfully built demjson3 bs4
# Installing collected packages: pyee, parse, fake-useragent, demjson3, websockets, w3lib, urllib3, cssselect, pyquery, pyppeteer, dateparser, bs4, requests-html, facebook_scraper
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
# Successfully installed bs4-0.0.1 cssselect-1.2.0 dateparser-1.2.0 demjson3-3.0.6 facebook_scraper-0.2.59 fake-useragent-1.4.0 parse-1.20.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-2.0.0 requests-html-0.10.0 urllib3-1.26.18 w3lib-2.1.2 websockets-10.4

# %%
from facebook_scraper import get_posts
import pandas as pd
import numpy as np

# %% [markdown]
# ## Crawl the data using facebook_scraper
# Now we can get the data from Facebook using the facebook_scraper library. We will be using the get_posts function to get the posts from the fanpage. This function will return a list of dictionaries, where each dictionary represents a post. We will be saving this list of dictionaries to a json file. More information about what you can do with the facebook_scraper library can be found here: https://github.com/kevinzg/facebook-scraper

# %% [markdown]
# ## Define variables
# First we have to define some variables that we will be using throughout the notebook.
# - FANPAGE_LINK: The link to the fanpage that we want to crawl data from. This can be found by going to the fanpage and copying the link from the address bar. For example, the link to the fanpage of the [Nintendo Switch](https://www.facebook.com/NintendoSwitch/) is https://www.facebook.com/NintendoSwitch/. We will be using this link as the value for FANPAGE_LINK.
#
# - COOKIE_PATH: The path to the cookie file that we will be using to authenticate with Facebook. This cookie file can be obtained by logging into Facebook and copying the cookie from the browser. For example, in Chromium, use extension [Get cookies.txt LOCALLY](https://chrome.google.com/webstore/detail/get-cookiestxt/bgaddhkoddajcdgocldbbfleckgcbcid) to get the cookie file. Then save the cookie to a file and use the path to this file as the value for COOKIE_PATH. <span style="color:red; font-weight:bold">USE COOKIE FROM A FAKE ACCOUNT, OTHERWISE YOUR REAL ACCOUNT MIGHT GET BANNED.</span>.
#
#
# - FOLDER_NAME: The name of the folder that we will be saving the data to. This folder will be created in the same directory as this notebook.

# %%
FANPAGE_LINK ="LiverpoolFC"
FOLDER_PATH = "/content/drive/MyDrive/python"
COOKIE_PATH = "/content/drive/MyDrive/python/www.facebook.com_cookies (1).txt"

PAGES_NUMBER = 15 # Number of pages to crawl

# %%
post_list = []
import time
for post in get_posts(FANPAGE_LINK,
                    options={"comments": True, "reactions": True, "allow_extra_requests": True},
                    extra_info=True, pages=PAGES_NUMBER, cookies=COOKIE_PATH):
    print(post)
    post_list.append(post)
    if len(post_list) % 2 == 0:
      time.sleep(10)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Convert list of dicts to df

# %% [markdown]
# Now we can convert the list of dictionaries to a pandas dataframe. We will be using the pandas library to do this. We will also be saving the dataframe to a xlxs or csv file.

# %%
# Initialize dataframe to scrape Facebook post
post_df_full = pd.DataFrame(columns=post_list[0].keys(), index=range(len(post_list)), data=post_list)

# To df
path=FOLDER_PATH + FANPAGE_LINK + ".csv"
post_df_full.to_csv(path, index=False)
print(path)
# Out:
# /content/drive/MyDrive/pythonLiverpoolFC6.csv

# %%
POST_IDS = post_df_full[100:500]['post_id'].values

# %%
POST_IDS

# %%
postids = pd.DataFrame(POST_IDS)

# %%
path=FOLDER_PATH  + "postids.csv"
postids.to_csv(path, index=False)
print(path)

# %%
POST_IDS=pd.read_csv("/content/drive/MyDrive/postids.csv")

# %%
id = POST_IDS[100:120].values.flatten()

# %%
id
# Out:
# array([894430725385093, 894427942052038, 894415262053306, 894407862054046,
#        894402835387882, 894401828721316, 894395958721903, 894382052056627,
#        894380925390073, 894375272057305, 894370892057743, 894368978724601,
#        894363978725101, 894352248726274, 894346722060160, 894343502060482,
#        894342355393930, 894337608727738, 894336522061180, 894334985394667])

# %%
post_list1 = []
import time
for post in get_posts(post_urls=id,
                    options={"comments": True, "reactions": True, "allow_extra_requests": True},
                    cookies=COOKIE_PATH):
    print(post)
    post_list1.append(post)
    if len(post_list1) % 2 == 0:
      time.sleep(20)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Initialize dataframe to scrape Facebook post
post_df_full = pd.DataFrame(columns=post_list1[0].keys(), index=range(len(post_list1)), data=post_list1)

# To df
path=FOLDER_PATH + FANPAGE_LINK + "5.csv"
post_df_full.to_csv(path, index=False)
print(path)

# %%
datas1 = pd.read_csv("/content/drive/MyDrive/pythonLiverpoolFC1.csv")
datas2 = pd.read_csv("/content/drive/MyDrive/pythonLiverpoolFC2.csv")
datas3 = pd.read_csv("/content/drive/MyDrive/pythonLiverpoolFC3.csv")
datas4 = pd.read_csv("/content/drive/MyDrive/pythonLiverpoolFC4.csv")
datas5 = pd.read_csv("/content/drive/MyDrive/pythonLiverpoolFC5.csv")

# %%
final1 = datas1[datas1['comments']>0]
final2 = datas2[datas2['comments']>0]
final3 = datas3[datas3['comments']>0]
final4 = datas4[datas4['comments']>0]
final5 = datas5[datas5['comments']>0]
final = pd.concat([final1,final2,final3,final4,final5],ignore_index=True)
# Out:
# <ipython-input-60-01605a96fa9a>:6: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   final = pd.concat([final1,final2,final3,final4,final5],ignore_index=True)

# %%
final['post_id'] = final['original_request_url']
final.drop('original_request_url',axis=1,inplace=True)
final
# Out:
#                                              post_url          post_id  \
# 0   https://facebook.com/story.php?story_fbid=pfbi...  901339178027581
# 1   https://facebook.com/story.php?story_fbid=pfbi...  901360151358817
# 2   https://facebook.com/story.php?story_fbid=pfbi...  901339551360877
# 3   https://facebook.com/story.php?story_fbid=pfbi...  901303768031122
# 4   https://facebook.com/story.php?story_fbid=pfbi...  900881971406635
# ..                                                ...              ...
# 74  https://facebook.com/story.php?story_fbid=pfbi...  895548368606662
# 75  https://facebook.com/story.php?story_fbid=pfbi...  895664538595045
# 76  https://facebook.com/story.php?story_fbid=pfbi...  895615255266640
# 77  https://facebook.com/story.php?story_fbid=pfbi...  895538875274278
# 78             https://m.facebook.com/895578365270329  895578365270329
#
#                                                  text  \
# 0   Back in Premier League action tomorrow 🙌\n\nTr...
# 1   Stevie G with the sublime 💫 On this day in 2007 🔴
# 2   Mo on his magical moment against Manchester Ci...
# 3   Two years ago today... simply STUNNING from Th...
# 4   On this day in 2019, the resilient Reds found ...
# ..                                                ...
# 74  Every angle of Diogo Jota18's fine finish from...
# 75  Liverpool Legends will take on AFC Ajax Legend...
# 76  Virgil van Dijk is optimistic we can continue ...
# 77  Watch the extended action from Sunday's 3-0 wi...
# 78                                       Liverpool FC
#
#                                             post_text  \
# 0   Back in Premier League action tomorrow 🙌\n\nTr...
# 1   Stevie G with the sublime 💫 On this day in 2007 🔴
# 2   Mo on his magical moment against Manchester Ci...
# 3   Two years ago today... simply STUNNING from Th...
# 4   On this day in 2019, the resilient Reds found ...
# ..                                                ...
# 74  Every angle of Diogo Jota18's fine finish from...
# 75  Liverpool Legends will take on AFC Ajax Legend...
# 76  Virgil van Dijk is optimistic we can continue ...
# 77  Watch the extended action from Sunday's 3-0 wi...
# 78                                       Liverpool FC
#
#                                           shared_text  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 74                                                NaN
# 75  LIVERPOOLFC.COM\nLFC Legends to face AFC Ajax ...
# 76  LIVERPOOLFC.COM\nVirgil van Dijk: It's going w...
# 77                                                NaN
# 78                                                NaN
#
#                                         original_text                 time  \
# 0            Back in Premier League action tomorrow 🙌  2023-11-24 11:50:00
# 1                                                 NaN  2023-11-24 11:01:14
# 2                                                 NaN  2023-11-24 10:01:22
# 3                                                 NaN  2023-11-24 08:22:26
# 4   On this day in 2019, the resilient Reds found ...  2023-11-23 12:35:05
# ..                                                ...                  ...
# 74  Every angle of Diogo Jota18's fine finish from...  2023-11-14 13:11:27
# 75  Liverpool Legends will take on AFC Ajax Legend...  2023-11-14 16:00:41
# 76                                                NaN  2023-11-14 15:07:44
# 77  Watch the extended action from Sunday's 3-0 wi...  2023-11-14 12:09:18
# 78                                                NaN  2023-11-14 00:00:00
#
#        timestamp                                              image  \
# 0   1.700827e+09  https://scontent-lga3-1.xx.fbcdn.net/v/t39.308...
# 1   1.700824e+09                                                NaN
# 2   1.700820e+09                                                NaN
# 3   1.700814e+09                                                NaN
# 4   1.700743e+09                                                NaN
# ..           ...                                                ...
# 74  1.699967e+09                                                NaN
# 75  1.699978e+09                                                NaN
# 76  1.699974e+09                                                NaN
# 77  1.699964e+09                                                NaN
# 78           NaN  https://scontent-lga3-2.xx.fbcdn.net/v/t39.308...
#
#                                      image_lowquality  ... reaction_count  \
# 0   https://scontent-lga3-1.xx.fbcdn.net/v/t39.308...  ...        31247.0
# 1   https://scontent-lga3-1.xx.fbcdn.net/v/t15.525...  ...         7412.0
# 2   https://scontent-lga3-2.xx.fbcdn.net/v/t15.525...  ...        11212.0
# 3   https://scontent-lga3-2.xx.fbcdn.net/v/t15.525...  ...        33732.0
# 4   https://scontent-lga3-2.xx.fbcdn.net/v/t15.525...  ...         8498.0
# ..                                                ...  ...            ...
# 74  https://scontent-lga3-1.xx.fbcdn.net/v/t15.525...  ...        70367.0
# 75  https://external-lga3-2.xx.fbcdn.net/emg1/v/t1...  ...        11818.0
# 76  https://external-lga3-2.xx.fbcdn.net/emg1/v/t1...  ...         8939.0
# 77  https://scontent-lga3-1.xx.fbcdn.net/v/t15.525...  ...        25232.0
# 78  https://scontent-lga3-2.xx.fbcdn.net/v/t39.308...  ...        13979.0
#
#    with       page_id sharers      image_id  \
# 0   NaN  6.792038e+10     NaN           NaN
# 1   NaN  6.792038e+10     NaN           NaN
# 2   NaN  6.792038e+10     NaN           NaN
# 3   NaN  6.792038e+10     NaN           NaN
# 4   NaN  6.792038e+10     NaN           NaN
# ..  ...           ...     ...           ...
# 74  NaN  6.792038e+10     NaN           NaN
# 75  NaN  6.792038e+10     NaN           NaN
# 76  NaN  6.792038e+10     NaN           NaN
# 77  NaN  6.792038e+10     NaN           NaN
# 78  NaN           NaN     NaN  2.000039e+15
#
#                                             image_ids  video_ids  videos  \
# 0                                                  []         []      []
# 1                                                  []        NaN     NaN
# 2                                                  []        NaN     NaN
# 3                                                  []        NaN     NaN
# 4                                                  []        NaN     NaN
# ..                                                ...        ...     ...
# 74                                                 []        NaN     NaN
# 75                                                 []        NaN     NaN
# 76                                                 []        NaN     NaN
# 77                                                 []        NaN     NaN
# 78  ['2000038503727934', '2000038503727934', '2000...        NaN     NaN
#
#     was_live                fetched_time
# 0      False  2023-11-26 03:22:14.201844
# 1      False  2023-11-26 03:24:33.043208
# 2      False  2023-11-26 03:25:58.090632
# 3      False  2023-11-26 03:27:30.182185
# 4      False  2023-11-26 03:29:20.102784
# ..       ...                         ...
# 74     False  2023-11-28 08:02:45.413059
# 75     False  2023-11-28 10:11:05.900207
# 76     False  2023-11-28 10:13:17.571370
# 77     False  2023-11-28 10:14:17.821346
# 78     False  2023-11-28 10:14:30.933866
#
# [79 rows x 53 columns]

# %%
datas = pd.read_csv("/content/drive/MyDrive/pythonLiverpoolFC.csv")
final0 = datas[datas['comments']>0]
final = pd.concat([final,final0],ignore_index=True)
# Out:
# <ipython-input-62-0c0d6cc535f8>:3: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   final = pd.concat([final,final0],ignore_index=True)
#                                               post_url            post_id  \
# 0    https://facebook.com/story.php?story_fbid=pfbi...    901339178027581
# 1    https://facebook.com/story.php?story_fbid=pfbi...    901360151358817
# 2    https://facebook.com/story.php?story_fbid=pfbi...    901339551360877
# 3    https://facebook.com/story.php?story_fbid=pfbi...    901303768031122
# 4    https://facebook.com/story.php?story_fbid=pfbi...    900881971406635
# ..                                                 ...                ...
# 116  https://facebook.com/LiverpoolFC/posts/9014187...    901418754686290
# 117  https://facebook.com/LiverpoolFC/posts/6825586...   6825586720887614
# 118  https://facebook.com/LiverpoolFC/posts/8955783...    895578365270329
# 119  https://facebook.com/LiverpoolFC/posts/8948211...    894821158679383
# 120  https://facebook.com/LiverpoolFC/posts/1016224...  10162246071672573
#
#                                                   text  \
# 0    Back in Premier League action tomorrow 🙌\n\nTr...
# 1    Stevie G with the sublime 💫 On this day in 2007 🔴
# 2    Mo on his magical moment against Manchester Ci...
# 3    Two years ago today... simply STUNNING from Th...
# 4    On this day in 2019, the resilient Reds found ...
# ..                                                 ...
# 116  Mohamed Salah believes his and Liverpool's lev...
# 117  We’re LIVE as Jürgen Klopp previews tomorrow’s...
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
#
#                                              post_text  \
# 0    Back in Premier League action tomorrow 🙌\n\nTr...
# 1    Stevie G with the sublime 💫 On this day in 2007 🔴
# 2    Mo on his magical moment against Manchester Ci...
# 3    Two years ago today... simply STUNNING from Th...
# 4    On this day in 2019, the resilient Reds found ...
# ..                                                 ...
# 116  Mohamed Salah believes his and Liverpool's lev...
# 117  We’re LIVE as Jürgen Klopp previews tomorrow’s...
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
#
#                                            shared_text  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 116  LIVERPOOLFC.COM\nMohamed Salah on Man City v L...
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
#
#                                          original_text                 time  \
# 0             Back in Premier League action tomorrow 🙌  2023-11-24 11:50:00
# 1                                                  NaN  2023-11-24 11:01:14
# 2                                                  NaN  2023-11-24 10:01:22
# 3                                                  NaN  2023-11-24 08:22:26
# 4    On this day in 2019, the resilient Reds found ...  2023-11-23 12:35:05
# ..                                                 ...                  ...
# 116                                                NaN  2023-11-24 14:00:11
# 117  We’re LIVE as Jürgen Klopp previews tomorrow’s...  2023-11-24 13:27:25
# 118                                                NaN  2023-11-14 14:18:40
# 119                                                NaN  2023-11-13 08:50:45
# 120                                                NaN  2023-06-08 10:01:23
#
#         timestamp                                              image  \
# 0    1.700827e+09  https://scontent-lga3-1.xx.fbcdn.net/v/t39.308...
# 1    1.700824e+09                                                NaN
# 2    1.700820e+09                                                NaN
# 3    1.700814e+09                                                NaN
# 4    1.700743e+09                                                NaN
# ..            ...                                                ...
# 116  1.700834e+09                                                NaN
# 117  1.700832e+09                                                NaN
# 118  1.699972e+09  https://scontent-iad3-1.xx.fbcdn.net/v/t39.308...
# 119  1.699865e+09  https://m.facebook.com/photo/view_full_size/?f...
# 120  1.686218e+09  https://scontent-iad3-1.xx.fbcdn.net/v/t39.308...
#
#                                       image_lowquality  ... reaction_count  \
# 0    https://scontent-lga3-1.xx.fbcdn.net/v/t39.308...  ...        31247.0
# 1    https://scontent-lga3-1.xx.fbcdn.net/v/t15.525...  ...         7412.0
# 2    https://scontent-lga3-2.xx.fbcdn.net/v/t15.525...  ...        11212.0
# 3    https://scontent-lga3-2.xx.fbcdn.net/v/t15.525...  ...        33732.0
# 4    https://scontent-lga3-2.xx.fbcdn.net/v/t15.525...  ...         8498.0
# ..                                                 ...  ...            ...
# 116  https://external-iad3-1.xx.fbcdn.net/emg1/v/t1...  ...         7547.0
# 117  https://scontent-iad3-1.xx.fbcdn.net/v/t15.525...  ...        12418.0
# 118  https://scontent-iad3-1.xx.fbcdn.net/v/t39.308...  ...        13795.0
# 119  https://scontent-iad3-1.xx.fbcdn.net/v/t39.308...  ...         3382.0
# 120  https://scontent-iad3-1.xx.fbcdn.net/v/t39.308...  ...        35284.0
#
#                                                   with       page_id sharers  \
# 0                                                  NaN  6.792038e+10     NaN
# 1                                                  NaN  6.792038e+10     NaN
# 2                                                  NaN  6.792038e+10     NaN
# 3                                                  NaN  6.792038e+10     NaN
# 4                                                  NaN  6.792038e+10     NaN
# ..                                                 ...           ...     ...
# 116                                                NaN  6.792038e+10     NaN
# 117  [{'name': 'AXA', 'link': 'https://facebook.com...  6.792038e+10     NaN
# 118                                                NaN  6.792038e+10     NaN
# 119                                                NaN  6.792038e+10     NaN
# 120                                                NaN  6.792038e+10     NaN
#
#          image_id              image_ids  video_ids  videos  was_live  \
# 0             NaN                     []         []      []     False
# 1             NaN                     []        NaN     NaN     False
# 2             NaN                     []        NaN     NaN     False
# 3             NaN                     []        NaN     NaN     False
# 4             NaN                     []        NaN     NaN     False
# ..            ...                    ...        ...     ...       ...
# 116           NaN                     []        NaN     NaN     False
# 117           NaN                     []        NaN     NaN     False
# 118  8.955784e+14    ['895578365270329']        NaN     NaN     False
# 119           NaN                     []        NaN     NaN     False
# 120  1.016225e+16  ['10162246071672573']        NaN     NaN     False
#
#                    fetched_time
# 0    2023-11-26 03:22:14.201844
# 1    2023-11-26 03:24:33.043208
# 2    2023-11-26 03:25:58.090632
# 3    2023-11-26 03:27:30.182185
# 4    2023-11-26 03:29:20.102784
# ..                          ...
# 116  2023-11-25 15:54:51.561276
# 117  2023-11-25 15:55:14.544979
# 118  2023-11-25 16:14:40.881012
# 119  2023-11-25 16:18:13.695622
# 120  2023-11-25 16:26:08.551776
#
# [121 rows x 53 columns]

# %%
path=FOLDER_PATH + "final"  + ".csv"
final.to_csv(path, index=False)
print(path)
# Out:
# /content/drive/MyDrive/pythonfinal.csv
